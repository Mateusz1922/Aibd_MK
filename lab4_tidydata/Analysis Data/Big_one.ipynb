# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('earthquake_data.csv')
df1
# Out:
#      In general, how worried are you about earthquakes?  \
# 0                                    Not at all worried
# 1                                      Somewhat worried
# 2                                        Not so worried
# 3                                        Not so worried
# 4                                        Not so worried
# ...                                                 ...
# 1008                                 Not at all worried
# 1009                                     Not so worried
# 1010                                     Not so worried
# 1011                                 Not at all worried
# 1012                                   Somewhat worried
#
#      How worried are you about the Big One, a massive, catastrophic earthquake?  \
# 0                                        Not so worried
# 1                                          Very worried
# 2                                      Somewhat worried
# ...

# %%
df = pd.read_csv('earthquake_data.csv')
df
# Out:
#      In general, how worried are you about earthquakes?  \
# 0                                    Not at all worried
# 1                                      Somewhat worried
# 2                                        Not so worried
# 3                                        Not so worried
# 4                                        Not so worried
# ...                                                 ...
# 1008                                 Not at all worried
# 1009                                     Not so worried
# 1010                                     Not so worried
# 1011                                 Not at all worried
# 1012                                   Somewhat worried
#
#      How worried are you about the Big One, a massive, catastrophic earthquake?  \
# 0                                        Not so worried
# 1                                          Very worried
# 2                                      Somewhat worried
# ...

# %%
# df.rename(columns = {'In general, how worried are you about earthquakes?':'General worry',\
#                      'How worried are you about the Big One, a massive, catastrophic earthquake?':'Big One worry',
#                      'Do you think the "Big One" will occur in your lifetime?':'Big One in your future lifetime',
#                      'Have you or anyone in your household taken any precautions for an earthquake (packed an\
#                      earthquake survival kit, prepared an evacuation plan, etc.)?':'Have you ever taken any precautions against earthquakes?'\
#                     }, inplace = True)
# df

# %%
df.columns = ['General worry', 'Big One worry', 'Big One will occur in your future lifetime?', 'Earthquake experience','Have you ever taken any precautions against earthquakes?', 'Familiarity with San Andreas fault line', 'Familiarity with Yellowstone Supervolcano', 'Age','Gender','Household total earnings per year', 'US Region']
df.head()
# Out:
#         General worry     Big One worry  \
# 0  Not at all worried    Not so worried
# 1    Somewhat worried      Very worried
# 2      Not so worried  Somewhat worried
# 3      Not so worried    Not so worried
# 4      Not so worried    Not so worried
#
#   Big One will occur in your future lifetime?        Earthquake experience  \
# 0                                          No  Yes, one or more minor ones
# 1                                          No  Yes, one or more minor ones
# 2                                          No  Yes, one or more minor ones
# 3                                          No  Yes, one or more minor ones
# 4                                         Yes  Yes, one or more minor ones
#
#   Have you ever taken any precautions against earthquakes?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# ...

# %%
big_one = df[['Big One will occur in your future lifetime?', 'Age', 'Gender']]
all_female = big_one['Gender']=='Female'
all_yes = big_one['Big One will occur in your future lifetime?']=='Yes'
female_worried = big_one[all_female & all_yes]
female_worried.describe()
# Out:
#        Big One will occur in your future lifetime?      Age  Gender
# count                                          224      224     224
# unique                                           1        4       1
# top                                            Yes  45 - 59  Female
# freq                                           224       61     224

# %%
big_one.index = big_one['Age']
big_one.drop('Age', axis=1, inplace=True)
big_one.head()
# Out:
# C:\Users\Mateusz\AppData\Local\Temp\ipykernel_6988\1048799593.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   big_one.drop('Age', axis=1, inplace=True)
#         Big One will occur in your future lifetime? Gender
# Age
# 18 - 29                                          No   Male
# 18 - 29                                          No   Male
# 18 - 29                                          No   Male
# 18 - 29                                          No   Male
# 18 - 29                                         Yes   Male

# %%
# yellowstone = df[['Familiarity with Yellowstone Supervolcano', 'Household total earnings per year', 'US Region']]
# yellowstone.head()
# Out:
#   Familiarity with Yellowstone Supervolcano Household total earnings per year  \
# 0                           Not so familiar              Prefer not to answer
# 1                       Not at all familiar                $75,000 to $99,999
# 2                         Somewhat familiar                $10,000 to $24,999
# 3                           Not so familiar                $25,000 to $49,999
# 4                        Extremely familiar                   $200,000 and up
#
#             US Region
# 0         New England
# 1  East North Central
# 2             Pacific
# 3  West South Central
# 4     Middle Atlantic

# %%
# yellowstone.index = yellowstone['US Region']
# yellowstone.drop('US Region', axis=1, inplace=True)
# yellowstone.head()
# Out:
# C:\Users\Mateusz\AppData\Local\Temp\ipykernel_6988\3875333538.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yellowstone.drop('US Region', axis=1, inplace=True)
#                    Familiarity with Yellowstone Supervolcano  \
# US Region
# New England                                  Not so familiar
# East North Central                       Not at all familiar
# Pacific                                    Somewhat familiar
# West South Central                           Not so familiar
# Middle Atlantic                           Extremely familiar
#
#                    Household total earnings per year
# US Region
# New England                     Prefer not to answer
# East North Central                $75,000 to $99,999
# Pacific                           $10,000 to $24,999
# ...

# %%
big_one1 = df[['Big One will occur in your future lifetime?', 'Age']]
yes_sum = (big_one1['Big One will occur in your future lifetime?'] == 'Yes').sum()
age_18 = big_one1['Age'] == '18 - 29'
no_sum = (big_one1['Big One will occur in your future lifetime?'] == 'No').sum()
yes_18_29 = (big_one1[yes_sum & age_18]).sum()
# print(yes_18_29)
# print(no_sum)
big_one1.index=big_one1['Age']
big_one1.drop('Age', axis=1, inplace=True)
# big_one1
# big_one1.describe()
big_one1.apply(pd.value_counts).plot(kind='bar')
# big_one1.plot(x=big_one1['Age'], y=big_one1['Big One will occur in your future lifetime?'], kind='bar')
# plt.figure()
# big_one.plot(kind='bar')
# Out:
# Big One will occur in your future lifetime?    0.0
# Age                                            0.0
# dtype: float64
# 577
# C:\Users\Mateusz\AppData\Local\Temp\ipykernel_6988\134232788.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   big_one1.drop('Age', axis=1, inplace=True)
# <AxesSubplot:>

# %%
# plt.plot(big_one1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 plt.plot(big_one1)
#
# File ~\anaconda33\envs\mateuszkrol\lib\site-packages\matplotlib\pyplot.py:2767, in plot(scalex, scaley, data, *args, **kwargs)
#    2765 @_copy_docstring_and_deprecators(Axes.plot)
#    2766 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2767     return gca().plot(
#    2768         *args, scalex=scalex, scaley=scaley,
#    2769         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda33\envs\mateuszkrol\lib\site-packages\matplotlib\axes\_axes.py:1635, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1393 """
#    1394 Plot y versus x as lines and/or markers.
#    1395
#    (...)
#    1632 (``'green'``) or hex strings (``'#008000'``).
#    1633 """
# ...
